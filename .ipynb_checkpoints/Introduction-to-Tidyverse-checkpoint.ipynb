# %% [markdown]
# <img src="images/banner_introRProg.png" align="left" />

# %% [markdown]
# <table style="float:right;">
#     <tr>
#         <td>
#             <div style="text-align: right"><a href="https://www.research.manchester.ac.uk/portal/syed.murtuzabaker.html" target="_blank">Syed Murtuza Baker</a></div>
#             <div style="text-align: right">Research Fellow</div>
#             <div style="text-align: right">University of Manchester</div>
#          </td>
#          <td>
#              <img src="images/Syed_Baker.jpg" width="50%" />
#          </td>
#      </tr>
# </table>

# %% [markdown]
# # Introduction to Tidyverse
# ****

# %% [markdown]
# #### About this Notebook
# This notebook introduces Tidyverse

# %% [markdown]
# Level: <code>beginner</code>

# %% [markdown]
# Duration: Approximately 2 hours to complete

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Learning Objectives:</b>
# <br/> At the end of this notebook you will be able to:
#
# - Describe the features of the Tidyverse R package
#
# - Explain the use of different functions such as Tibble, Pipe,
#
# - Explore deployr, Mutate, Slice & Arrange
#
#
# </div>

# %% [markdown]
# <a id="top"></a>
#
# <b>Table of contents</b><br>
#
# 1.0 [Introduction](#intro)
#
# 2.0 [About Tidyverse](#tidyverse)
#
# 3.0 [Your Turn](#yourturn)
#
# *****

# %% [markdown]
# <a id="intro"></a>
#
# ## Introduction
#
#
# This notebook intrdouces `tidyverse`, a collection of R packages popular for data wrangling.
#
# For help in using this Jupyter notebook please refer to the [Jupyter Notebook User Guide](https://online.manchester.ac.uk/bbcswebdav/orgs/I3116-ADHOC-I3HS-HUB-1/Jupyter%20Notebooks/content/index.html#/)

# %% [markdown]
# *****
# [back to the top](#top)

# %% [markdown]
# <a id="tidyverse"></a>
#
# ## About Tidyverse

# %% [markdown]
# tidyverse.org defines Tidyverse as
#
# >The tidyverse is an opinionated collection of R packages designed for data science. All packages share an underlying design philosophy, grammar, and data structures.

# %%
library(tidyverse)
library(dplyr)
library(scater)

# %% [markdown]
# We will use single-cell RNA sequencing on 6826 stem cells from Chronic myelomonocytic leukaemia (CMML) patients and healthy controls using the droplet-based, ultra-high-throughput 10x platform. We found substantial inter and intra-patient heterogeneity, with CMML stem cells displaying distinctive transcriptional programs. Compared with normal controls, CMML stem cells exhibited transcriptomes characterized by increased expression of myeloid-lineage and cell cycle genes, and lower expression of genes selectively expressed by normal haematopoietic stem cells.

# %%
sce <- readRDS('/mnt/sce.rds')
sce
# Out:
# class: SingleCellExperiment
# dim: 12695 6826
# metadata(0):
# assays(3): counts logcounts norm_exprs
# rownames(12695): FO538757.2 AP006222.2 ... AC004556.1 AC240274.1
# rowData names(12): id symbol ... total_counts log10_total_counts
# colnames(6826): AAACCTGCACCGATAT-1 AAACGGGCACGACTCG-1 ...
#   TTTGGTTTCATCTGCC-11 TTTGTCAGTAGGAGTC-11
# colData names(59): barcode Sample ... sizeFactor cellType
# reducedDimNames(1): tSNE
# mainExpName: NULL
# altExpNames(0):

# %% [markdown]
# *****
# [back to the top](#top)

# %% [markdown]
# ### Tibble
#
# Tibbles are data-frames
# tibble() does much less: it never changes the type of the inputs (e.g. it never converts strings to factors!)
# it never changes the names of variables, and it never creates row names.
# tibble can have column names that are not valid R variable names, aka non-syntactic names.

# %%
tb <- tibble(
  `:)` = "smile", 
  ` ` = "space",
  `2000` = "number"
)
tb
# Out:
#   :)          2000
# 1 smile space number

# %% [markdown]
# ### Pipe %>%
#
# Pipe %>% passes the output from one stage to the other.

# %%
tbl_df(colData(sce))[1:5,]
# Out:
#   barcode            Sample total_features log10_total_features
# 1 AAACCTGCACCGATAT-1 BC543  2152           3.333044
# 2 AAACGGGCACGACTCG-1 BC543  2078           3.317854
# 3 AAAGCAATCCTAAGTG-1 BC543  2493           3.396896
# 4 AAAGTAGGTGATGATA-1 BC543  2298           3.361539
# 5 AAAGTAGTCTCGCTTG-1 BC543  2343           3.369958
#   pct_counts_top_50_features pct_counts_top_100_features
# 1 47.58468                   64.94609
# 2 46.25919                   63.97836
# 3 49.27632                   67.14031
# 4 43.84055                   61.52083
# 5 48.50873                   65.67959
#   pct_counts_top_200_features pct_counts_top_500_features
# 1 73.96214                    83.26683
# 2 74.47798                    83.97160
# 3 75.58654                    83.53050
# 4 72.48097                    82.09871
# 5 75.49354                    84.05766
#   total_features_endogenous log10_total_features_endogenous ⋯ pct_counts_Mt
# 1 2142                      3.331022                        ⋯ 2.657271
# 2 2067                      3.315551                        ⋯ 2.789754
# 3 2482                      3.394977                        ⋯ 3.218558
# 4 2288                      3.359646                        ⋯ 3.814357
# 5 2333                      3.368101                        ⋯ 2.861809
#   pct_counts_in_top_50_features_Mt pct_counts_in_top_100_features_Mt
# 1 100                              100
# 2 100                              100
# 3 100                              100
# 4 100                              100
# 5 100                              100
#   pct_counts_in_top_200_features_Mt pct_counts_in_top_500_features_Mt CellCycle
# 1 100                               100                               G1
# 2 100                               100                               G1
# 3 100                               100                               G1
# 4 100                               100                               G1
# 5 100                               100                               G1
#   Cluster Phase sizeFactor cellType
# 1 2       S     0.9487532  HSC
# 2 2       G1    0.9866038  HSC
# 3 2       G1    1.2639782  HSC
# 4 2       G2M   1.0392552  HSC
# 5 2       G1    0.9423322  HSC

# %%
tbl_df(colData(sce)) %>%
  group_by(Sample) %>%
  summarise(
    total.features = mean(total_features),
    total.counts = mean(total_counts)
  )
# Out:
#    Sample total.features total.counts
# 1  BC278  2971.597       18434.975
# 2  BC416  2070.396        9094.933
# 3  BC543  1947.178       10966.411
# 4  BC572  1471.253        5862.217
# 5  BC746  2565.624       13558.324
# 6  BC776  2330.206       10740.006
# 7  BC786  2507.971       12530.953
# 8  HV1    2263.642       10735.622
# 9  HV2    2408.250       12868.908
# 10 HV3    2283.051       11753.533

# %% [markdown]
# `summarise()` ungrouping output (override with `.groups` argument)

# %% [markdown]
# ### dplyr - Functions as verbs.
#
# The most useful
#
# <code>select()</code>: select columns
#
# <code>mutate()</code>: create new variables, change existing
#
# <code>filter()</code>: subset your data by some criterion
#
# <code>summarize()</code>: summarize your data in some way
#
# <code>group_by()</code>: group your data by a variable
#
# <code>slice()</code>: grab specific rows
#
# <code>select()</code>: select an observation
#
# Some others
#
# <code>count()</code>: count your data
#
# <code>arrange()</code>: arrange your data by a column or variable
#
# <code>distinct()</code>: gather all distinct values of a variable
#
# <code>n_distinct()</code>: count how many distinct values you have (only works with summarize)
#
# <code>n()</code>: count how many observation you have for a subgroup
#
# <code>sample_n()</code>: Grab an N sample of your data
#
# <code>ungroup()</code>: ungroup grouped data by a variable
#
# <code>top_n()</code>: get the top N number of entries from a data frame
#
#
# To make it easier we copy the metadata for our <code>SingleCellExperiment</code> object <code>sce</code> to <code>d</code>

# %%
d <- tbl_df(colData(sce))

# %%
d %>% 
  select(Sample, Cluster, cellType) %>%
  head(10)
# Out:
#    Sample Cluster cellType
# 1  BC543  2       HSC
# 2  BC543  2       HSC
# 3  BC543  2       HSC
# 4  BC543  2       HSC
# 5  BC543  2       HSC
# 6  BC543  2       HSC
# 7  BC543  2       HSC
# 8  BC543  6       HSC
# 9  BC543  6       HSC
# 10 BC543  15      HSC

# %% [markdown]
# #### Filter : To select rows

# %%
d %>% 
  filter(cellType == "HSC") %>%
  head(10)
# Out:
#    barcode            Sample total_features log10_total_features
# 1  AAACCTGCACCGATAT-1 BC543  2152           3.333044
# 2  AAACGGGCACGACTCG-1 BC543  2078           3.317854
# 3  AAAGCAATCCTAAGTG-1 BC543  2493           3.396896
# 4  AAAGTAGGTGATGATA-1 BC543  2298           3.361539
# 5  AAAGTAGTCTCGCTTG-1 BC543  2343           3.369958
# 6  AACACGTGTTGGTAAA-1 BC543  1658           3.219846
# 7  AACACGTTCAGGTAAA-1 BC543  1889           3.276462
# 8  AACCATGCACGACGAA-1 BC543   883           2.946452
# 9  AACCATGTCATAGCAC-1 BC543   812           2.910091
# 10 AACGTTGTCTCGTTTA-1 BC543  1611           3.207365
#    pct_counts_top_50_features pct_counts_top_100_features
# 1  47.58468                   64.94609
# 2  46.25919                   63.97836
# 3  49.27632                   67.14031
# 4  43.84055                   61.52083
# 5  48.50873                   65.67959
# 6  47.34871                   65.40645
# 7  50.92943                   69.62995
# 8  46.95035                   62.26950
# 9  45.69509                   59.89080
# 10 47.84624                   64.84460
#    pct_counts_top_200_features pct_counts_top_500_features
# 1  73.96214                    83.26683
# 2  74.47798                    83.97160
# 3  75.58654                    83.53050
# 4  72.48097                    82.09871
# 5  75.49354                    84.05766
# 6  76.03575                    85.48134
# 7  78.85542                    86.55766
# 8  73.68794                    86.41844
# 9  71.73457                    86.89626
# 10 74.53653                    84.37841
#    total_features_endogenous log10_total_features_endogenous ⋯ pct_counts_Mt
# 1  2142                      3.331022                        ⋯ 2.657271
# 2  2067                      3.315551                        ⋯ 2.789754
# 3  2482                      3.394977                        ⋯ 3.218558
# 4  2288                      3.359646                        ⋯ 3.814357
# 5  2333                      3.368101                        ⋯ 2.861809
# 6  1648                      3.217221                        ⋯ 2.186254
# 7  1879                      3.274158                        ⋯ 3.020654
# 8   873                      2.941511                        ⋯ 2.234043
# 9   801                      2.904174                        ⋯ 2.015960
# 10 1600                      3.204391                        ⋯ 1.785714
#    pct_counts_in_top_50_features_Mt pct_counts_in_top_100_features_Mt
# 1  100                              100
# 2  100                              100
# 3  100                              100
# 4  100                              100
# 5  100                              100
# 6  100                              100
# 7  100                              100
# 8  100                              100
# 9  100                              100
# 10 100                              100
#    pct_counts_in_top_200_features_Mt pct_counts_in_top_500_features_Mt
# 1  100                               100
# 2  100                               100
# 3  100                               100
# 4  100                               100
# 5  100                               100
# 6  100                               100
# 7  100                               100
# 8  100                               100
# 9  100                               100
# 10 100                               100
#    CellCycle Cluster Phase sizeFactor cellType
# 1  G1        2       S     0.9487532  HSC
# 2  G1        2       G1    0.9866038  HSC
# 3  G1        2       G1    1.2639782  HSC
# 4  G1        2       G2M   1.0392552  HSC
# 5  G1        2       G1    0.9423322  HSC
# 6  G1        2       G1    0.5750319  HSC
# 7  G1        2       G1    0.9193944  HSC
# 8  G1        6       G1    0.1917033  HSC
# 9  G1        6       G1    0.1792775  HSC
# 10 G1        15      G1    0.5052210  HSC

# %%
d %>% 
  select(barcode, Sample, total_features, cellType, Cluster) %>%
  filter(Sample == "BC572") %>%
  head(10)
# Out:
#    barcode            Sample total_features cellType Cluster
# 1  AAACCTGTCCAAGTAC-2 BC572  1258           HSC      7
# 2  AAAGATGGTTGTCGCG-2 BC572  1436           HSC      7
# 3  AAAGCAATCACCGTAA-2 BC572  1074           HSC      7
# 4  AAATGCCTCGGTTCGG-2 BC572   917           HSC      7
# 5  AACTCAGGTCTTCGTC-2 BC572  1090           HSC      7
# 6  AACTCTTAGTGGGCTA-2 BC572   983           HSC      7
# 7  AAGACCTAGCCCTAAT-2 BC572  2829           HSC      11
# 8  AAGGCAGCAGCATACT-2 BC572  1202           HSC      7
# 9  AAGTCTGAGAATCTCC-2 BC572  2352           HSC      11
# 10 AAGTCTGGTAAACCTC-2 BC572  2776           HSC      11

# %%
d %>% 
  filter(cellType == "Erythrocytes", pct_counts_Mt > 1.5) %>% 
  select(barcode, Sample, pct_counts_Mt, cellType, Cluster) %>%
  head(10)
# Out:
#    barcode            Sample pct_counts_Mt cellType     Cluster
# 1  AAGGAGCAGTTAGGTA-1 BC543  4.455730      Erythrocytes 17
# 2  AGTGGGATCATGTAGC-3 BC746  2.919859      Erythrocytes 9
# 3  GAACATCAGCCGATTT-3 BC746  4.329392      Erythrocytes 17
# 4  GATCAGTTCCTCATTA-3 BC746  4.152797      Erythrocytes 17
# 5  CCATGTCAGTCCAGGA-6 HV3    4.567626      Erythrocytes 17
# 6  TTAGGACGTAAGTTCC-6 HV3    3.249836      Erythrocytes 17
# 7  GCACTCTGTATTACCG-8 BC786  2.820549      Erythrocytes 17
# 8  AAAGATGCAGTCCTTC-9 BC278  3.578209      Erythrocytes 17
# 9  AACCGCGGTAGCTAAA-9 BC278  2.954553      Erythrocytes 17
# 10 AACGTTGTCCGTAGTA-9 BC278  3.894991      Erythrocytes 17

# %% [markdown]
# #### Mutate
#
# To create new variables in the data table:

# %%
d_exp <- d
d_exp <- cbind(d_exp, t(logcounts(sce)[c('KLF4','RUNX1','EGR1'),]))

# %%
d_exp %>% head(10)
# Out:
#                    barcode            Sample total_features
# AAACCTGCACCGATAT-1 AAACCTGCACCGATAT-1 BC543  2152
# AAACGGGCACGACTCG-1 AAACGGGCACGACTCG-1 BC543  2078
# AAAGCAATCCTAAGTG-1 AAAGCAATCCTAAGTG-1 BC543  2493
# AAAGTAGGTGATGATA-1 AAAGTAGGTGATGATA-1 BC543  2298
# AAAGTAGTCTCGCTTG-1 AAAGTAGTCTCGCTTG-1 BC543  2343
# AACACGTGTTGGTAAA-1 AACACGTGTTGGTAAA-1 BC543  1658
# AACACGTTCAGGTAAA-1 AACACGTTCAGGTAAA-1 BC543  1889
# AACCATGCACGACGAA-1 AACCATGCACGACGAA-1 BC543   883
# AACCATGTCATAGCAC-1 AACCATGTCATAGCAC-1 BC543   812
# AACGTTGTCTCGTTTA-1 AACGTTGTCTCGTTTA-1 BC543  1611
#                    log10_total_features pct_counts_top_50_features
# AAACCTGCACCGATAT-1 3.333044             47.58468
# AAACGGGCACGACTCG-1 3.317854             46.25919
# AAAGCAATCCTAAGTG-1 3.396896             49.27632
# AAAGTAGGTGATGATA-1 3.361539             43.84055
# AAAGTAGTCTCGCTTG-1 3.369958             48.50873
# AACACGTGTTGGTAAA-1 3.219846             47.34871
# AACACGTTCAGGTAAA-1 3.276462             50.92943
# AACCATGCACGACGAA-1 2.946452             46.95035
# AACCATGTCATAGCAC-1 2.910091             45.69509
# AACGTTGTCTCGTTTA-1 3.207365             47.84624
#                    pct_counts_top_100_features pct_counts_top_200_features
# AAACCTGCACCGATAT-1 64.94609                    73.96214
# AAACGGGCACGACTCG-1 63.97836                    74.47798
# AAAGCAATCCTAAGTG-1 67.14031                    75.58654
# AAAGTAGGTGATGATA-1 61.52083                    72.48097
# AAAGTAGTCTCGCTTG-1 65.67959                    75.49354
# AACACGTGTTGGTAAA-1 65.40645                    76.03575
# AACACGTTCAGGTAAA-1 69.62995                    78.85542
# AACCATGCACGACGAA-1 62.26950                    73.68794
# AACCATGTCATAGCAC-1 59.89080                    71.73457
# AACGTTGTCTCGTTTA-1 64.84460                    74.53653
#                    pct_counts_top_500_features total_features_endogenous
# AAACCTGCACCGATAT-1 83.26683                    2142
# AAACGGGCACGACTCG-1 83.97160                    2067
# AAAGCAATCCTAAGTG-1 83.53050                    2482
# AAAGTAGGTGATGATA-1 82.09871                    2288
# AAAGTAGTCTCGCTTG-1 84.05766                    2333
# AACACGTGTTGGTAAA-1 85.48134                    1648
# AACACGTTCAGGTAAA-1 86.55766                    1879
# AACCATGCACGACGAA-1 86.41844                     873
# AACCATGTCATAGCAC-1 86.89626                     801
# AACGTTGTCTCGTTTA-1 84.37841                    1600
#                    log10_total_features_endogenous ⋯
# AAACCTGCACCGATAT-1 3.331022                        ⋯
# AAACGGGCACGACTCG-1 3.315551                        ⋯
# AAAGCAATCCTAAGTG-1 3.394977                        ⋯
# AAAGTAGGTGATGATA-1 3.359646                        ⋯
# AAAGTAGTCTCGCTTG-1 3.368101                        ⋯
# AACACGTGTTGGTAAA-1 3.217221                        ⋯
# AACACGTTCAGGTAAA-1 3.274158                        ⋯
# AACCATGCACGACGAA-1 2.941511                        ⋯
# AACCATGTCATAGCAC-1 2.904174                        ⋯
# AACGTTGTCTCGTTTA-1 3.204391                        ⋯
#                    pct_counts_in_top_200_features_Mt
# AAACCTGCACCGATAT-1 100
# AAACGGGCACGACTCG-1 100
# AAAGCAATCCTAAGTG-1 100
# AAAGTAGGTGATGATA-1 100
# AAAGTAGTCTCGCTTG-1 100
# AACACGTGTTGGTAAA-1 100
# AACACGTTCAGGTAAA-1 100
# AACCATGCACGACGAA-1 100
# AACCATGTCATAGCAC-1 100
# AACGTTGTCTCGTTTA-1 100
#                    pct_counts_in_top_500_features_Mt CellCycle Cluster Phase
# AAACCTGCACCGATAT-1 100                               G1        2       S
# AAACGGGCACGACTCG-1 100                               G1        2       G1
# AAAGCAATCCTAAGTG-1 100                               G1        2       G1
# AAAGTAGGTGATGATA-1 100                               G1        2       G2M
# AAAGTAGTCTCGCTTG-1 100                               G1        2       G1
# AACACGTGTTGGTAAA-1 100                               G1        2       G1
# AACACGTTCAGGTAAA-1 100                               G1        2       G1
# AACCATGCACGACGAA-1 100                               G1        6       G1
# AACCATGTCATAGCAC-1 100                               G1        6       G1
# AACGTTGTCTCGTTTA-1 100                               G1        15      G1
#                    sizeFactor cellType KLF4     RUNX1    EGR1
# AAACCTGCACCGATAT-1 0.9487532  HSC      0.000000 7.477600 6.485672
# AAACGGGCACGACTCG-1 0.9866038  HSC      6.429876 8.003639 6.429876
# AAAGCAATCCTAAGTG-1 1.2639782  HSC      0.000000 6.077144 8.381875
# AAAGTAGGTGATGATA-1 1.0392552  HSC      0.000000 6.355761 6.355761
# AAAGTAGTCTCGCTTG-1 0.9423322  HSC      0.000000 6.495360 8.069622
# AACACGTGTTGGTAAA-1 0.5750319  HSC      0.000000 7.201707 0.000000
# AACACGTTCAGGTAAA-1 0.9193944  HSC      0.000000 0.000000 0.000000
# AACCATGCACGACGAA-1 0.1917033  HSC      0.000000 0.000000 0.000000
# AACCATGTCATAGCAC-1 0.1792775  HSC      0.000000 0.000000 0.000000
# AACGTTGTCTCGTTTA-1 0.5052210  HSC      0.000000 0.000000 7.387244

# %%
d_exp %>% 
  mutate(Klf4Diff = abs(KLF4 - RUNX1)) %>%
  select(barcode, Sample, cellType, Klf4Diff) %>%
  head(10)
# Out:
#                    barcode            Sample cellType Klf4Diff
# AAACCTGCACCGATAT-1 AAACCTGCACCGATAT-1 BC543  HSC      7.477600
# AAACGGGCACGACTCG-1 AAACGGGCACGACTCG-1 BC543  HSC      1.573763
# AAAGCAATCCTAAGTG-1 AAAGCAATCCTAAGTG-1 BC543  HSC      6.077144
# AAAGTAGGTGATGATA-1 AAAGTAGGTGATGATA-1 BC543  HSC      6.355761
# AAAGTAGTCTCGCTTG-1 AAAGTAGTCTCGCTTG-1 BC543  HSC      6.495360
# AACACGTGTTGGTAAA-1 AACACGTGTTGGTAAA-1 BC543  HSC      7.201707
# AACACGTTCAGGTAAA-1 AACACGTTCAGGTAAA-1 BC543  HSC      0.000000
# AACCATGCACGACGAA-1 AACCATGCACGACGAA-1 BC543  HSC      0.000000
# AACCATGTCATAGCAC-1 AACCATGTCATAGCAC-1 BC543  HSC      0.000000
# AACGTTGTCTCGTTTA-1 AACGTTGTCTCGTTTA-1 BC543  HSC      0.000000

# %% [markdown]
# #### Arrange
#
# To order the data by a particular variable:

# %%
d_exp %>% 
  mutate(Klf4Diff = abs(KLF4 - RUNX1)) %>% 
  arrange(desc(Klf4Diff)) 
  head(5)
# Out:
#                     barcode             Sample total_features
# AGATCTGCAACTGCTA-5  AGATCTGCAACTGCTA-5  HV2    1611
# TTGCGTCCATACCATG-2  TTGCGTCCATACCATG-2  BC572   911
# CTCGAAATCACTGGGC-7  CTCGAAATCACTGGGC-7  BC572  1009
# TGGCTGGGTCGTTGTA-7  TGGCTGGGTCGTTGTA-7  BC572   782
# GCATGCGCAGGAATGC-7  GCATGCGCAGGAATGC-7  BC572   819
# GTCTCGTTCAGGCCCA-2  GTCTCGTTCAGGCCCA-2  BC572  1025
# CAAGATCTCACTCTTA-2  CAAGATCTCACTCTTA-2  BC572  1028
# ATTATCCAGACCTAGG-7  ATTATCCAGACCTAGG-7  BC572   885
# AGATTGCAGAGTGACC-2  AGATTGCAGAGTGACC-2  BC572   895
# CTCGGAGTCTATCGCC-2  CTCGGAGTCTATCGCC-2  BC572   825
# AGCGGTCTCCCTAACC-7  AGCGGTCTCCCTAACC-7  BC572   936
# GAAACTCTCAGCGATT-2  GAAACTCTCAGCGATT-2  BC572  1182
# TCGTACCTCTCTGTCG-7  TCGTACCTCTCTGTCG-7  BC572   932
# TCCACACTCTATCGCC-7  TCCACACTCTATCGCC-7  BC572   808
# GCGGGTTAGTACGTTC-2  GCGGGTTAGTACGTTC-2  BC572   882
# TCGGGACGTTTGCATG-2  TCGGGACGTTTGCATG-2  BC572   982
# TCTGAGATCTTGTACT-1  TCTGAGATCTTGTACT-1  BC543  1319
# GACGGCTTCCGCATCT-2  GACGGCTTCCGCATCT-2  BC572  1189
# AGCTCCTAGAAGATTC-2  AGCTCCTAGAAGATTC-2  BC572  1065
# ACGGGCTTCTTGACGA-7  ACGGGCTTCTTGACGA-7  BC572  1006
# CATGCCTGTTAGATGA-2  CATGCCTGTTAGATGA-2  BC572   957
# CAGTCCTTCGACAGCC-7  CAGTCCTTCGACAGCC-7  BC572   835
# GATCGTATCACTATTC-7  GATCGTATCACTATTC-7  BC572   952
# TCTATTGCAGTGGGAT-6  TCTATTGCAGTGGGAT-6  HV3    2067
# CTGAAACCACATTCGA-7  CTGAAACCACATTCGA-7  BC572   809
# ATGCGATTCAAGATCC-7  ATGCGATTCAAGATCC-7  BC572   841
# CCCAGTTGTTAGAACA-2  CCCAGTTGTTAGAACA-2  BC572  1090
# GCTGGGTGTCACACGC-2  GCTGGGTGTCACACGC-2  BC572  1365
# GGGTCTGCACAACGTT-11 GGGTCTGCACAACGTT-11 BC416  1231
# GCATGCGGTACGCACC-4  GCATGCGGTACGCACC-4  HV1    2106
# ⋮                   ⋮                   ⋮      ⋮
# TGGACGCTCACCACCT-11 TGGACGCTCACCACCT-11 BC416  1145
# TGGCGCACATATGCTG-11 TGGCGCACATATGCTG-11 BC416  1570
# TGGCTGGAGAAACGCC-11 TGGCTGGAGAAACGCC-11 BC416  3099
# TTCGAAGGTAAGTAGT-11 3.272074                        ⋯
# TTCGGTCCACCATGTA-11 3.303844                        ⋯
# TTCTACAGTCCGACGT-11 3.116608                        ⋯
# TTCTTAGGTATATCCG-11 3.365113                        ⋯
# TTCTTAGGTCATCCCT-11 3.332438                        ⋯
# TTGAACGAGTAGCGGT-11 3.409595                        ⋯
# TTGGAACCAAGCTGGA-11 3.416973                        ⋯
# TTGGAACCAAGTTGTC-11 3.227630                        ⋯
# TTGTAGGTCCTCATTA-11 3.449478                        ⋯
# TTTACTGCAATCCAAC-11 3.323871                        ⋯
# TTTCCTCCACGAAATA-11 3.294025                        ⋯
# TTTGCGCCACAGACTT-11 3.227372                        ⋯
# TTTGCGCTCTCCAGGG-11 3.511081                        ⋯
# TTTGTCAGTAGGAGTC-11 3.196176                        ⋯
#                     pct_counts_in_top_500_features_Mt CellCycle Cluster Phase
# AGATCTGCAACTGCTA-5  100                               G1        15      G1
# TTGCGTCCATACCATG-2  100                               G1        7       G1
# CTCGAAATCACTGGGC-7  100                               G1        7       G1
# TGGCTGGGTCGTTGTA-7  100                               S         7       G1
# GCATGCGCAGGAATGC-7  100                               G1        7       S
# GTCTCGTTCAGGCCCA-2  100                               G1        7       G1
# CAAGATCTCACTCTTA-2  100                               G1        7       G1
# ATTATCCAGACCTAGG-7  100                               G1        7       S
# AGATTGCAGAGTGACC-2  100                               G1        7       G1
# CTCGGAGTCTATCGCC-2  100                               G1        7       G1
# AGCGGTCTCCCTAACC-7  100                               G1        7       G1
# GAAACTCTCAGCGATT-2  100                               G1        7       G1
# TCGTACCTCTCTGTCG-7  100                               G1        7       G2M
# TCCACACTCTATCGCC-7  100                               S         7       G1
# GCGGGTTAGTACGTTC-2  100                               G1        7       G1
# TCGGGACGTTTGCATG-2  100                               G1        7       G1
# TCTGAGATCTTGTACT-1  100                               G1        6       G1
# GACGGCTTCCGCATCT-2  100                               G1        7       G1
# AGCTCCTAGAAGATTC-2  100                               G1        7       G1
# ACGGGCTTCTTGACGA-7  100                               G1        7       G1
# CATGCCTGTTAGATGA-2  100                               G1        7       G1
# CAGTCCTTCGACAGCC-7  100                               G1        7       G1
# GATCGTATCACTATTC-7  100                               G1        7       G1
# TCTATTGCAGTGGGAT-6  100                               G1        15      G1
# CTGAAACCACATTCGA-7  100                               G1        7       G1
# ATGCGATTCAAGATCC-7  100                               G1        7       G1
# CCCAGTTGTTAGAACA-2  100                               S         7       G1
# GCTGGGTGTCACACGC-2  100                               G1        7       G1
# GGGTCTGCACAACGTT-11 100                               G2M       1       G1
# GCATGCGGTACGCACC-4  100                               G1        15      G1
# ⋮                   ⋮                                 ⋮         ⋮       ⋮
# TGGACGCTCACCACCT-11 100                               S         11      G1
# TGGCGCACATATGCTG-11 100                               G1        12      G1
# TGGCTGGAGAAACGCC-11 100                               G1        12      S
# TGGCTGGGTATAGTAG-11 100                               G1        12      G1
# TGGGAAGCACCCTATC-11 100                               G1        12      G2M
# TGGTTAGCAGCCTTGG-11 100                               G1        3       G2M
# TTTGCGCTCTCCAGGG-11 0
# TTTGTCAGTAGGAGTC-11 0
# [1] 5

# %% [markdown]
# #### Group by + sumarize : forget about loops
#
# First: group by a particular variables Second: summarize the data with new statistics. Summarize: Turn many rows into one.
#
# Examples:
#
# ```
# min(x) - minimum value of vector x.
#
# max(x) - maximum value of vector x.
#
# mean(x) - mean value of vector x.
#
# median(x) - median value of vector x.
#
# quantile(x, p) - pth quantile of vector x.
#
# sd(x) - standard deviation of vector x.
#
# var(x) - variance of vector x.
#
# IQR(x) - Inter Quartile Range (IQR) of vector x.
#
# diff(range(x)) - total range of vector x.
#
# ```

# %%
d %>% 
  group_by(cellType) %>% 
  summarise(mean_total_counts = mean(total_counts, na.rm = TRUE), sd_total_counts = sd(total_counts), 
     mean_pct_Mt_count = mean(pct_counts_Mt), count = n()) %>% 
  #ungroup() %>% 
  slice_max(., n=20, order_by = mean_total_counts)  # note here, it does
# Out:
#    cellType          mean_total_counts sd_total_counts mean_pct_Mt_count count
# 1  BM & Prog.        30704.000                NA       3.5858520            1
# 2  Erythrocytes      29884.306         9744.2316       3.1332549          265
# 3  MEP               26098.203         8539.9938       2.8879160           74
# 4  GMP               12125.685         5481.6378       2.2918437          146
# 5  CMP               11096.714         4576.0677       2.5725066            7
# 6  HSC               11036.224         4885.0916       2.2195699         6282
# 7  Monocytes         10733.375         4540.2326       2.8227165            8
# 8  Pro-Myelocyte      6665.000         5488.5628       1.7153164            2
# 9  NK_cell            5750.000                NA       0.7652174            1
# 10 Platelets          5619.800         2339.1910       1.3455238            5
# 11 Fibroblasts        5456.000                NA       1.7778592            1
# 12 Pre-B_cell_CD34-   4251.500         2107.8853       1.9252839            2
# 13 CD8+ T-cells       3868.545         1199.3128       2.0299289           11
# 14 B-cells            3556.857          869.1990       2.9144949           14
# 15 Endothelial cells  3396.000                NA       0.8244994            1
# 16 Adipocytes         3131.667          554.8129       2.4295231            3
# 17 Pro-B_cell_CD34+   2661.000                NA       1.8414130            1
# 18 CD4+ T-cells       2351.000                NA       2.5095704            1
# 19 NK cells           2279.000                NA       1.8429136            1

# %% [markdown]
# `summarise()` ungrouping output (override with `.groups` argument)

# %% [markdown]
# <div class="alert alert-success">
#     <strong>Note:</strong> <code>mutate()</code> either changes an existing column or adds a new one. summarise() calculates a single value (per group). As you can see, in the first example, new column is added.</a>.
# </div>

# %% [markdown]
# *****
# [back to the top](#top)

# %% [markdown]
# <a id="yourturn"></a>
# ## Your Turn

# %% [markdown]
# Let us look at the mpg dataset first

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Task 1</b><br/>
#    <p>Select only teh audi cars from the above list</p>
# </div>

# %%
mpg %>% 
  filter(manufacturer == "audi")
# Out:
#    manufacturer model      displ year cyl trans      drv cty hwy fl class
# 1  audi         a4         1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2  audi         a4         1.8   1999 4   manual(m5) f   21  29  p  compact
# 3  audi         a4         2.0   2008 4   manual(m6) f   20  31  p  compact
# 4  audi         a4         2.0   2008 4   auto(av)   f   21  30  p  compact
# 5  audi         a4         2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6  audi         a4         2.8   1999 6   manual(m5) f   18  26  p  compact
# 7  audi         a4         3.1   2008 6   auto(av)   f   18  27  p  compact
# 8  audi         a4 quattro 1.8   1999 4   manual(m5) 4   18  26  p  compact
# 9  audi         a4 quattro 1.8   1999 4   auto(l5)   4   16  25  p  compact
# 10 audi         a4 quattro 2.0   2008 4   manual(m6) 4   20  28  p  compact
# 11 audi         a4 quattro 2.0   2008 4   auto(s6)   4   19  27  p  compact
# 12 audi         a4 quattro 2.8   1999 6   auto(l5)   4   15  25  p  compact
# 13 audi         a4 quattro 2.8   1999 6   manual(m5) 4   17  25  p  compact
# 14 audi         a4 quattro 3.1   2008 6   auto(s6)   4   17  25  p  compact
# 15 audi         a4 quattro 3.1   2008 6   manual(m6) 4   15  25  p  compact
# 16 audi         a6 quattro 2.8   1999 6   auto(l5)   4   15  24  p  midsize
# 17 audi         a6 quattro 3.1   2008 6   auto(s6)   4   17  25  p  midsize
# 18 audi         a6 quattro 4.2   2008 8   auto(s6)   4   16  23  p  midsize

# %% [markdown]
# Let us look at how many cars are there in the list

# %%
table(mpg$manufacturer)
# Out:
#       audi  chevrolet      dodge       ford      honda    hyundai       jeep
#         18         19         37         25          9         14          8
# land rover    lincoln    mercury     nissan    pontiac     subaru     toyota
#          4          3          4         13          5         14         34
# volkswagen
#         27

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Task2</b></br>
# <p>How many Ford cars are there?</p>
# </div>

# %%
mpg %>% 
  filter(manufacturer == "ford") %>%
  summarize(Ford_cars = n())
# Out:
#   Ford_cars
# 1 25

# %% [markdown]
# *****
# [back to the top](#top)

# %% [markdown]
# ### Notebook details
# <br>
# <i>Notebook created by <strong>Syed Murtuza Baker</strong>. Other contributors include Fran Hooley...
#
# Publish date: May 2021<br>
# Review date: May 2022</i>
#
# Please give your feedback using the button below:

# %% [markdown]
# <a class="typeform-share button" href="https://hub11.typeform.com/to/jUk0oK0O" data-mode="popup" style="display:inline-block;text-decoration:none;background-color:#3A7685;color:white;cursor:pointer;font-family:Helvetica,Arial,sans-serif;font-size:18px;line-height:45px;text-align:center;margin:0;height:45px;padding:0px 30px;border-radius:22px;max-width:100%;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;font-weight:bold;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;" target="_blank">Rate this notebook </a> <script> (function() { var qs,js,q,s,d=document, gi=d.getElementById, ce=d.createElement, gt=d.getElementsByTagName, id="typef_orm_share", b="https://embed.typeform.com/"; if(!gi.call(d,id)){ js=ce.call(d,"script"); js.id=id; js.src=b+"embed.js"; q=gt.call(d,"script")[0]; q.parentNode.insertBefore(js,q) } })() </script>

# %% [markdown]
# ****
#
# ## Your Notes:
